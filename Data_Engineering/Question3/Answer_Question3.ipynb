# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.1 Explain which parts of the script are inefficient.

# %% [markdown]
# Ans: มีการเรียกใช้ dp เพื่อสร้าง dp_inflow และ dp_outflow แยกกัน แล้วนำกลับมา Merge ใหม่โดยไม่จำเป็น ทำให้เสียเวลาในการอ่านข้อมูลซ้ำซ้อนและสิ้นเปลืองทรัพยากรในการ ประมวลผล

# %% [markdown]
# 3.2 Provide at least 3 improvements to optimize performance.

# %% [markdown]
# Ans:
# 1. ใช้ case => when => then => else => end ในส่วนของการแยกเงินออกเพื่อไม่ต้องมาเรียกและ join ซ้ำแทนที่จะเรียกมา join ใหม่
#
# 2. หากข้อมูลมีจำนวนเยอะมากๆ ควรแบ่ง PARTITION => CREATE TABLE ```[table]``` PARTITION OF ```[columns]``` เพิ่อเพิ่มความไว
#
# 3. ใน tnx_dp ควร ```select``` ค่าที่จะดูมาตั้งแต่แรกเพิ่อประหยัดค่า query data และควรเพิ่ม limit และ scope ข้อมูลก่อนทำการ ```select```
